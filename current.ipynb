# %%
import nest_asyncio

nest_asyncio.apply()

# %%
import torchvision
torchvision.disable_beta_transforms_warning()

# %%
import os
import json

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader, Settings
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.llms.ollama import Ollama

# bge-base embedding model
Settings.embed_model = HuggingFaceEmbedding(model_name="BAAI/bge-base-en-v1.5")

# ollama
Settings.llm = Ollama(model="llama3.3", request_timeout=360.0, temperature=0)

# %%
format_title = lambda x: x.lower()

# %%
from llama_index.core.tools import FunctionTool
from llama_index.core.tools import QueryEngineTool, ToolMetadata
from llama_index.core.agent import ReActAgent, FunctionCallingAgent, AgentRunner, FunctionCallingAgentWorker, StructuredPlannerAgent

# %%
from llama_parse import LlamaParse

# %%
parser = LlamaParse(
    result_type="markdown",
    premium_mode=False,  # "markdown" and "text" are available
    api_key = 'llx-EOjy0QMOscFhy9ZHigbX9YbfWO7X2nVdP3TdFjZ1QMXB7mWm'
)
file_extractor = {".pdf": parser}

# %%
with open('file_descriptions.json', 'r') as file:
    file_descriptions = json.load(file)

pdf_dir = 'data'

query_engine_tools = []
agents = {}

# Iterate through each PDF in the directory
for file_name in os.listdir(pdf_dir):
    if file_name.endswith(".pdf"):
        # Load the document
        file_path = os.path.join(pdf_dir, file_name)
        reader = SimpleDirectoryReader(input_files=[file_path], file_extractor=file_extractor)
        #reader = SimpleDirectoryReader(input_files=[file_path])
        documents = reader.load_data()
        description = file_descriptions[format_title(file_name[:-4])]
        
        # Create an index for the document
        vector_index = VectorStoreIndex.from_documents(documents)
        query_engine_tool = QueryEngineTool.from_defaults(
            vector_index.as_query_engine(
                similarity_top_k=5,
            ),
            name=f"{file_name[:-4]} query engine",
            description=description
        )
        
        query_engine_tools.append(query_engine_tool)

        agents[f"{format_title(file_name[:-4])}"] = FunctionCallingAgent.from_tools(
            [query_engine_tool],
            llm = Settings.llm,
            verbose=True,
            system_prompt=f"""\
            You are a specialized agent designed to answer questions about {format_title(file_name[:-4])} using the American \
            College of Radiology (ACR) appropriateness criteria. You have access to a tool that allows you to query a document \
            from the ACR regarding {format_title(file_name[:-4])}. This document {description.lower()} \
            In your response, provide as much relevant detail from the documents as possible. If a given scenario has a table with \
            ratings of the appropriate next steps, return each next step and its rating in a json format. Prioritize putting next steps \
            with high appropriateness ratings first. This may be indicated by a high number or a "usually appropriate" phrase. Do not \
            come up with ratings that are not explicitly given in the tools. \
            You must always use at least one of the tools provided when answering a question. Do NOT rely on prior knowledge.
            """
        )
# Out:
# Started parsing the file under job_id 1015c123-1edd-4882-883c-ac871ed55719
# Started parsing the file under job_id 3b998941-3176-4761-83dd-62fe12d9ec2d
# Started parsing the file under job_id 6c9d3754-9eb9-4483-8a8e-d7820092d5de
# Started parsing the file under job_id 86efd569-f017-4a59-8b61-3af2ef4bfce5
# Started parsing the file under job_id a27c2550-873f-4cce-a221-8667ff55f9ed
# Started parsing the file under job_id afdcefde-1d9c-4daf-9701-b1da97d7107c
# Started parsing the file under job_id 10b4d51c-5901-41e8-a6a4-a0645f6f1c37
# Started parsing the file under job_id ee400e0e-3183-48d9-bd1f-e427212feb4e
# Started parsing the file under job_id 214bab24-d1cc-436e-9f3d-5e9d5e892eb6
# Started parsing the file under job_id 2fe9041d-ca16-4f19-9dca-a7dc77964a49
# Started parsing the file under job_id 6e35c087-33e2-465a-83e3-378c2954b808
# Started parsing the file under job_id 356336d6-33f8-4a7b-9224-7137e308a628
# Started parsing the file under job_id 1e963773-78ed-48af-8fbe-3d344dfb89e9
# Started parsing the file under job_id e1890a28-74d5-48ea-bd23-b8403b92e73c
# Started parsing the file under job_id 79128740-4298-4920-8f2e-0eae40c79542
# Started parsing the file under job_id 556cd685-05e0-4774-a13d-d8678ebcdfdd
# Started parsing the file under job_id 8733e25c-af23-445b-869f-7807cf8fae93
# Started parsing the file under job_id e049664b-50dc-4bfc-9ff1-305dca84edd9
# Started parsing the file under job_id d12a1f89-55e0-4bda-86b3-9dcbc872d949
# Started parsing the file under job_id 9d19ae10-4d69-44e3-a6fe-3a76d49c44e6

# %%
from llama_index.core.objects import SimpleToolNodeMapping, ObjectIndex

# %%
tools = []
for agent_name, agent in agents.items():
    tool = QueryEngineTool(
        query_engine = agent,
        metadata=ToolMetadata(
            name=f'tool_{agent_name}',
            description=f'This tool uses the {agent_name} agent to answer queries. {agent_name} has access to a document which {file_descriptions[agent_name].lower()}'
        )
    )
    tools.append(tool)

tool_mapping = SimpleToolNodeMapping.from_objects(tools)

# %%
fallback_tool = FunctionTool.from_defaults(
    lambda x: 'No relevant information contained in the American College of Radiology (ACR) appropriateness criteria',
    name="Fallback Tool",
    description="Handles queries with no relevance to interventional radiology  American College of Radiology (ACR) appropriateness criteria.\
    This tool can be called when no other tool can."
)
tools.append(fallback_tool)

# %%
obj_index = ObjectIndex.from_objects(
    tools + [fallback_tool],
    index_cls=VectorStoreIndex,
)

# %%
obj_retriever = obj_index.as_retriever(similarity_top_k=3)

# %%
agent_worker = FunctionCallingAgentWorker.from_tools(
    tool_retriever=obj_retriever,
    llm=Settings.llm, 
    system_prompt=""" \
    You are a top-level agent designed to answer queries regarding planning, follow-up, and next steps for various interventional radiology \
    scenarios. Choose the most appropriate agent in the object index based on the user query. These agents have access to documents from \
    the American College of Radiology (ACR) appropriateness criteria. The agent will output a json if there is a matching scenario in its document. \
    You will receive queries regarding planning, follow-up, and next steps for various scenarios in interventional radiology and medicine more \
    generally. Use the agents and tools provided to you to best respond to these queries as if you were answering a question for a physician and \
    in a way that would be most useful for clincial practice. \
    For example, if a next step is regarded as "usually appropriate," you should respond as such. If you receive a json format text, interpret the text \
    and use the information in your response. Do not respond with json text. \
    If a response cannot be answered with the ACR Appropriateness criteria, state that the information is not contained within the ACR AC. \
    Prompt the user for additional information if it would be useful in narrowing down the next steps or recommendations. \
    Always use a provided agent to answer the question. Do NOT rely on prior knowledge.\
    """,
    verbose=True
)
top_agent = AgentRunner(agent_worker)

# %%
top_agent.chat('30 year old patient with fibroids who still wants to have kids. What should I do?')
# Out:
# Added user message to memory: 30 year old patient with fibroids who still wants to have kids. What should I do?
# === Calling Function ===
# Calling function: tool_management of uterine fibroids with args: {"input": "30 year old patient with fibroids who still wants to have kids"}
# > Running step 502f0a96-48ff-400d-9077-cd9b1015b4cc. Step input: 30 year old patient with fibroids who still wants to have kids
# Added user message to memory: 30 year old patient with fibroids who still wants to have kids
# === Calling Function ===
# Calling function: Management of Uterine Fibroids query engine with args: {"input": "30 year old patient with fibroids who still wants to have kids"}
# === Function Output ===
# For a 30-year-old patient with uterine fibroids who wishes to preserve fertility, especially when considering the presence of concurrent adenomyosis, medical management is often considered a first-line approach due to its less invasive nature. This can include the use of progestin IUDs or combined oral contraceptives, which have been shown to reduce heavy menstrual bleeding and pain in patients with fibroids and adenomyosis. However, for symptoms related to bulk, such as pressure or pain due to the size of the fibroids, other treatments like laparoscopic or open myomectomy might be more appropriate, offering a direct approach to removing the fibroids while preserving fertility. MR-guided high-frequency focused ultrasound ablation and uterine artery embolization are also options for managing symptoms without immediate recourse to surgery, though their effectiveness in patients with both fibroids and adenomyosis may vary. Hysteroscopic myomectomy remains a viable option, particularly for submucosal fibroids impacting fertility. The choice of treatment should be tailored to the patient's specific symptoms, desire for future fertility, and the characteristics of her fibroids and adenomyosis.
# > Running step 796264f0-1a82-49c2-9fb6-c4dc115d47c6. Step input: None
# === LLM Response ===
# In this scenario, the American College of Radiology (ACR) appropriateness criteria would likely recommend the following next steps:
#
# ```
# {
#   "next_steps": [
#     {
#       "step": "Medical management with progestin IUDs or combined oral contraceptives",
#       "rating": "Usually Appropriate"
#     },
#     {
#       "step": "Laparoscopic or open myomectomy for bulk symptoms",
#       "rating": "Usually Appropriate"
#     },
#     {
#       "step": "MR-guided high-frequency focused ultrasound ablation",
#       "rating": "May Be Appropriate"
#     },
#     {
#       "step": "Uterine artery embolization",
#       "rating": "May Be Appropriate"
#     },
#     {
#       "step": "Hysteroscopic myomectomy for submucosal fibroids",
#       "rating": "Usually Appropriate"
#     }
#   ]
# }
# ```
#
# These recommendations prioritize treatments that balance symptom relief with the preservation of fertility, considering the patient's age and desire to have children. The ratings are based on the ACR appropriateness criteria, which evaluate the appropriateness of various procedures for managing uterine fibroids in different clinical scenarios.
# === Function Output ===
# In this scenario, the American College of Radiology (ACR) appropriateness criteria would likely recommend the following next steps:
#
# ```
# {
#   "next_steps": [
#     {
#       "step": "Medical management with progestin IUDs or combined oral contraceptives",
#       "rating": "Usually Appropriate"
#     },
#     {
#       "step": "Laparoscopic or open myomectomy for bulk symptoms",
#       "rating": "Usually Appropriate"
#     },
#     {
#       "step": "MR-guided high-frequency focused ultrasound ablation",
#       "rating": "May Be Appropriate"
#     },
#     {
#       "step": "Uterine artery embolization",
#       "rating": "May Be Appropriate"
#     },
#     {
#       "step": "Hysteroscopic myomectomy for submucosal fibroids",
#       "rating": "Usually Appropriate"
#     }
#   ]
# }
# ```
#
# These recommendations prioritize treatments that balance symptom relief with the preservation of fertility, considering the patient's age and desire to have children. The ratings are based on the ACR appropriateness criteria, which evaluate the appropriateness of various procedures for managing uterine fibroids in different clinical scenarios.
# === LLM Response ===
# For a 30-year-old patient with fibroids who still wants to have kids, the American College of Radiology (ACR) appropriateness criteria recommend medical management with progestin IUDs or combined oral contraceptives as usually appropriate. Laparoscopic or open myomectomy for bulk symptoms is also considered usually appropriate. Other options like MR-guided high-frequency focused ultrasound ablation and uterine artery embolization may be appropriate, while hysteroscopic myomectomy for submucosal fibroids is usually appropriate.
#
# Can you provide more information about the patient's specific symptoms and medical history? This would help in narrowing down the most suitable next steps.
# AgentChatResponse(response="For a 30-year-old patient with fibroids who still wants to have kids, the American College of Radiology (ACR) appropriateness criteria recommend medical management with progestin IUDs or combined oral contraceptives as usually appropriate. Laparoscopic or open myomectomy for bulk symptoms is also considered usually appropriate. Other options like MR-guided high-frequency focused ultrasound ablation and uterine artery embolization may be appropriate, while hysteroscopic myomectomy for submucosal fibroids is usually appropriate. \n\nCan you provide more information about the patient's specific symptoms and medical history? This would help in narrowing down the most suitable next steps.", sources=[ToolOutput(content='In this scenario, the American College of Radiology (ACR) appropriateness criteria would likely recommend the following next steps:\n\n```\n{\n  "next_steps": [\n    {\n      "step": "Medical management with progestin IUDs or combined oral contraceptives",\n      "rating": "Usually Appropriate"\n    },\n    {\n      "step": "Laparoscopic or open myomectomy for bulk symptoms",\n      "rating": "Usually Appropriate"\n    },\n    {\n      "step": "MR-guided high-frequency focused ultrasound ablation",\n      "rating": "May Be Appropriate"\n    },\n    {\n      "step": "Uterine artery embolization",\n      "rating": "May Be Appropriate"\n    },\n    {\n      "step": "Hysteroscopic myomectomy for submucosal fibroids",\n      "rating": "Usually Appropriate"\n    }\n  ]\n}\n```\n\nThese recommendations prioritize treatments that balance symptom relief with the preservation of fertility, considering the patient\'s age and desire to have children. The ratings are based on the ACR appropriateness criteria, which evaluate the appropriateness of various procedures for managing uterine fibroids in different clinical scenarios.', tool_name='tool_management of uterine fibroids', raw_input={'input': '30 year old patient with fibroids who still wants to have kids'}, raw_output=Response(response='In this scenario, the American College of Radiology (ACR) appropriateness criteria would likely recommend the following next steps:\n\n```\n{\n  "next_steps": [\n    {\n      "step": "Medical management with progestin IUDs or combined oral contraceptives",\n      "rating": "Usually Appropriate"\n    },\n    {\n      "step": "Laparoscopic or open myomectomy for bulk symptoms",\n      "rating": "Usually Appropriate"\n    },\n    {\n      "step": "MR-guided high-frequency focused ultrasound ablation",\n      "rating": "May Be Appropriate"\n    },\n    {\n      "step": "Uterine artery embolization",\n      "rating": "May Be Appropriate"\n    },\n    {\n      "step": "Hysteroscopic myomectomy for submucosal fibroids",\n      "rating": "Usually Appropriate"\n    }\n  ]\n}\n```\n\nThese recommendations prioritize treatments that balance symptom relief with the preservation of fertility, considering the patient\'s age and desire to have children. The ratings are based on the ACR appropriateness criteria, which evaluate the appropriateness of various procedures for managing uterine fibroids in different clinical scenarios.', source_nodes=[NodeWithScore(node=TextNode(id_='916bf4e8-8039-408a-8ac1-252cc2a36ef5', embedding=None, metadata={'file_path': 'data/Management of Uterine Fibroids.pdf', 'file_name': 'Management of Uterine Fibroids.pdf', 'file_type': 'application/pdf', 'file_size': 452498, 'creation_date': '2025-01-12', 'last_modified_date': '2024-04-10'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={<NodeRelationship.SOURCE: '1'>: RelatedNodeInfo(node_id='18f0a230-7765-494a-b9fe-47f9b8efe254', node_type='4', metadata={'file_path': 'data/Management of Uterine Fibroids.pdf', 'file_name': 'Manageme ...

# %%
top_agent.chat('The patient has heavy bleeding and submucosal fibroids')
# Out:
# Added user message to memory: The patient has heavy bleeding and submucosal fibroids
# === Calling Function ===
# Calling function: tool_management of uterine fibroids with args: {"input": "heavy bleeding and submucosal fibroids"}
# > Running step 33ebee6a-dd4a-4233-893b-0dfe01d56a31. Step input: heavy bleeding and submucosal fibroids
# Added user message to memory: heavy bleeding and submucosal fibroids
# === Calling Function ===
# Calling function: Management of Uterine Fibroids query engine with args: {"input": "heavy bleeding and submucosal fibroids"}
# === Function Output ===
# For postmenopausal patients experiencing heavy bleeding and diagnosed with submucosal fibroids, particularly those with negative endometrial biopsy results, it's crucial to first rule out underlying causes such as uterine sarcoma due to the increased risk in this age group. Given the absence of relevant literature on medical management for this specific condition, uterine artery embolization (UAE) could be considered as a treatment option after thorough diagnostic workup. UAE has been supported by evidence as a safe and effective procedure for treating fibroids in postmenopausal patients, leading to complete fibroid necrosis and symptom resolution in a significant percentage of cases. However, the primary step should always be to investigate and exclude more serious conditions before proceeding with any minimally invasive therapy.
# > Running step 8e747d45-9e65-4028-be87-ca6dd80a5a46. Step input: None
# > Running step 60c3a796-a8e5-4b5c-b918-1a2d54375b81. Step input: None
# === LLM Response ===
# Given the scenario of heavy bleeding and submucosal fibroids, the American College of Radiology (ACR) Appropriateness Criteria suggest the following management options:
#
# 1. **Uterine Artery Embolization (UAE)**: This procedure is often recommended for women with symptomatic uterine fibroids who wish to preserve their uterus and have failed or are not candidates for medical or surgical therapy. UAE has a high appropriateness rating for treating submucosal fibroids, especially when heavy bleeding is a significant symptom.
#
# 2. **Myomectomy**: This surgical procedure involves the removal of fibroids while leaving the uterus in place. It's usually appropriate for women who wish to preserve fertility and have symptomatic fibroids that are causing heavy bleeding. Myomectomy has a high appropriateness rating, especially for submucosal fibroids.
#
# 3. **Magnetic Resonance-guided Focused Ultrasound (MRgFUS)**: This is a non-invasive treatment option that uses high-frequency sound waves to heat and destroy fibroid tissue under MRI guidance. It's usually appropriate for women with symptomatic uterine fibroids who are seeking a non-invasive treatment option.
#
# 4. **Hysterectomy**: Although more invasive, hysterectomy (surgical removal of the uterus) is sometimes considered for women with severe symptoms from submucosal fibroids who have completed childbearing and have failed other treatments. It has a high appropriateness rating in such scenarios due to its definitive nature in resolving symptoms.
#
# The appropriateness ratings can vary based on specific patient factors, including desire for future fertility, overall health status, and the presence of other gynecological conditions. Therefore, it's essential to consult with a healthcare provider to determine the most appropriate treatment plan.
#
# In terms of imaging, MRI is often recommended as the initial imaging test for evaluating uterine fibroids due to its high sensitivity and specificity in characterizing fibroid location, size, and number, which are critical factors in determining the best treatment approach.
#
# Here is a summary of next steps with their appropriateness ratings in JSON format:
#
# ```json
# {
#   "next_steps": [
#     {
#       "step": "Uterine Artery Embolization (UAE)",
#       "rating": "Usually Appropriate"
#     },
#     {
#       "step": "Myomectomy",
#       "rating": "Usually Appropriate"
#     },
#     {
#       "step": "Magnetic Resonance-guided Focused Ultrasound (MRgFUS)",
#       "rating": "May Be Appropriate"
#     },
#     {
#       "step": "Hysterectomy",
#       "rating": "Usually Appropriate for severe symptoms and completed childbearing"
#     }
#   ]
# }
# ```
#
# Note: The ratings provided are based on general guidelines and may vary depending on the specific clinical scenario and patient factors. Always consult the latest ACR Appropriateness Criteria and clinical judgment for the most appropriate management plan.
# === Function Output ===
# Given the scenario of heavy bleeding and submucosal fibroids, the American College of Radiology (ACR) Appropriateness Criteria suggest the following management options:
#
# 1. **Uterine Artery Embolization (UAE)**: This procedure is often recommended for women with symptomatic uterine fibroids who wish to preserve their uterus and have failed or are not candidates for medical or surgical therapy. UAE has a high appropriateness rating for treating submucosal fibroids, especially when heavy bleeding is a significant symptom.
#
# 2. **Myomectomy**: This surgical procedure involves the removal of fibroids while leaving the uterus in place. It's usually appropriate for women who wish to preserve fertility and have symptomatic fibroids that are causing heavy bleeding. Myomectomy has a high appropriateness rating, especially for submucosal fibroids.
#
# 3. **Magnetic Resonance-guided Focused Ultrasound (MRgFUS)**: This is a non-invasive treatment option that uses high-frequency sound waves to heat and destroy fibroid tissue under MRI guidance. It's usually appropriate for women with symptomatic uterine fibroids who are seeking a non-invasive treatment option.
#
# 4. **Hysterectomy**: Although more invasive, hysterectomy (surgical removal of the uterus) is sometimes considered for women with severe symptoms from submucosal fibroids who have completed childbearing and have failed other treatments. It has a high appropriateness rating in such scenarios due to its definitive nature in resolving symptoms.
#
# The appropriateness ratings can vary based on specific patient factors, including desire for future fertility, overall health status, and the presence of other gynecological conditions. Therefore, it's essential to consult with a healthcare provider to determine the most appropriate treatment plan.
#
# In terms of imaging, MRI is often recommended as the initial imaging test for evaluating uterine fibroids due to its high sensitivity and specificity in characterizing fibroid location, size, and number, which are critical factors in determining the best treatment approach.
#
# Here is a summary of next steps with their appropriateness ratings in JSON format:
#
# ```json
# {
#   "next_steps": [
#     {
#       "step": "Uterine Artery Embolization (UAE)",
#       "rating": "Usually Appropriate"
#     },
#     {
#       "step": "Myomectomy",
#       "rating": "Usually Appropriate"
#     },
#     {
#       "step": "Magnetic Resonance-guided Focused Ultrasound (MRgFUS)",
#       "rating": "May Be Appropriate"
#     },
#     {
#       "step": "Hysterectomy",
#       "rating": "Usually Appropriate for severe symptoms and completed childbearing"
#     }
#   ]
# }
# ```
#
# Note: The ratings provided are based on general guidelines and may vary depending on the specific clinical scenario and patient factors. Always consult the latest ACR Appropriateness Criteria and clinical judgment for the most appropriate management plan.
# === LLM Response ===
# For a patient with heavy bleeding and submucosal fibroids, uterine artery embolization (UAE) is usually an appropriate treatment option. Myomectomy is also usually appropriate, especially if the patient wishes to preserve fertility. Magnetic Resonance-guided Focused Ultrasound (MRgFUS) may be appropriate in certain cases. Hysterectomy could be considered for severe symptoms in patients who have completed childbearing.
#
# To further guide management, can you provide more details about the patient's medical history, current symptoms, and any previous treatments or interventions she has undergone for her fibroids? Additionally, what are her preferences regarding future fertility preservation?
# AgentChatResponse(response="For a patient with heavy bleeding and submucosal fibroids, uterine artery embolization (UAE) is usually an appropriate treatment option. Myomectomy is also usually appropriate, especially if the patient wishes to preserve fertility. Magnetic Resonance-guided Focused Ultrasound (MRgFUS) may be appropriate in certain cases. Hysterectomy could be considered for severe symptoms in patients who have completed childbearing.\n\nTo further guide management, can you provide more details about the patient's medical history, current symptoms, and any previous treatments or interventions she has undergone for her fibroids? Additionally, what are her preferences regarding future fertility preservation?", sources=[ToolOutput(content='Given the scenario of heavy bleeding and submucosal fibroids, the American College of Radiology (ACR) Appropriateness Criteria suggest the following management options:\n\n1. **Uterine Artery Embolization (UAE)**: This procedure is often recommended for women with symptomatic uterine fibroids who wish to preserve their uterus and have failed or are not candidates for medical or surgical therapy. UAE has a high appropriateness rating for treating submucosal fibroids, especially when heavy bleeding is a significant symptom.\n\n2. **Myomectomy**: This surgical procedure involves the removal of fibroids while leaving the uterus in place. It\'s usually appropriate for women who wish to preserve fertility and have symptomatic fibroids that are causing heavy bleeding. Myomectomy has a high appropriateness rating, especially for submucosal fibroids.\n\n3. **Magnetic Resonance-guided Focused Ultrasound (MRgFUS)**: This is a non-invasive treatment option that uses high-frequency sound waves to heat and destroy fibroid tissue under MRI guidance. It\'s usually appropriate for women with symptomatic uterine fibroids who are seeking a non-invasive treatment option.\n\n4. **Hysterectomy**: Although more invasive, hysterectomy (surgical removal of the uterus) is sometimes considered for women with severe symptoms from submucosal fibroids who have completed childbearing and have failed other treatments. It has a high appropriateness rating in such scenarios due to its definitive nature in resolving symptoms.\n\nThe appropriateness ratings can vary based on specific patient factors, including desire for future fertility, overall health status, and the presence of other gynecological conditions. Therefore, it\'s essential to consult with a healthcare provider to determine the most appropriate treatment plan.\n\nIn terms of imaging, MRI is often recommended as the initial imaging test for evaluating uterine fibroids due to its high sensitivity and specificity in characterizing fibroid location, size, and number, which are critical factors in determining the best treatment approach. \n\nHere is a summary of next steps with their appropriateness ratings in JSON format:\n\n```json\n{\n  "next_steps": [\n    {\n      "step": "Uterine Artery Embolization (UAE)",\n      "rating": "Usually Appropriate"\n    },\n    {\n      "step": "Myomectomy",\n      "rating": "Usually Appropriate"\n    },\n    {\n      "step": "Magnetic Resonance-guided Focused Ultrasound (MRgFUS)",\n      "rating": "May Be Appropriate"\n    },\n    {\n      "step": "Hysterectomy",\n      "rating": "Usually Appropriate for severe symptoms and completed childbearing"\n    }\n  ]\n}\n```\n\nNote: The ratings provided are based on general guidelines and may vary depending on the specific clinical scenario and patient factors. Always consult the latest ACR Appropriateness Criteria and clinical judgment for the most appropriate management plan.', tool_name='tool_management of uterine fibroids', raw_input={'input': 'heavy bleeding and submucosal fibroids'}, raw_output=Response(response='Given the scenario of heavy bleeding and submucosal fibroids, the American College of Radiology (ACR) Appropriateness Criteria suggest the following management op ...

# %%
response = top_agent.query(
    'What kind of catheter should I use for central line? '
    'On a separate note, I also want to know if my patient with a DVT needs a stent. '
    'Also, do you know why blood is red? '
)
# Out:
# Added user message to memory: What kind of catheter should I use for central line? On a separate note, I also want to know if my patient with a DVT needs a stent. Also, do you know why blood is red?
# === Calling Function ===
# Calling function: tool_central venous access device and site selection with args: {"input": "central line catheter selection"}
# > Running step 9b9f6374-9ec3-46e8-9268-bb03884805c8. Step input: central line catheter selection
# Added user message to memory: central line catheter selection
# === Calling Function ===
# Calling function: Central Venous Access Device and Site Selection query engine with args: {"input": "central line catheter selection"}
# === Function Output ===
# For central line catheter selection, several options are considered based on patient needs and clinical scenarios.
#
# 1. **Nontunneled Central Venous Catheter**: Usually appropriate for acutely ill patients requiring infusion of an irritant medication, hemodynamic monitoring, or frequent blood draws for 2 weeks or shorter. It's also usually appropriate for patients with acute renal failure requiring central venous access for renal replacement therapy anticipated to last 2 weeks or shorter.
#
# 2. **PICC (Peripherally Inserted Central Catheter)**: Usually appropriate for acutely ill patients requiring infusion of an irritant medication, hemodynamic monitoring, or frequent blood draws for 2 weeks or shorter. It may be appropriate for patients with cancer diagnosis requiring central venous access for weekly chemotherapy infusion for more than 2 weeks.
#
# 3. **Midline Catheter**: May be appropriate for certain clinical scenarios, such as administration of nonvesicant drugs over a prolonged period (6-30 days) in patients with difficult IV access or contraindication to central venous catheterization. However, it's not advocated for vesicant medications due to the risk of severe tissue injury.
#
# 4. **Tunneled Central Venous Catheter**: May be appropriate for acutely ill patients and is usually appropriate for patients requiring central venous access for more than 2 weeks, such as those with renal failure needing long-term renal replacement therapy.
#
# 5. **Arm Port and Chest Port**: Usually not appropriate for acute illness requiring short-term therapy or monitoring but are usually appropriate for patients with cancer diagnosis requiring central venous access for weekly chemotherapy infusion for more than 2 weeks.
#
# The choice of central line catheter depends on the specific clinical scenario, including the anticipated duration of therapy, the type of medication to be administered, patient factors such as difficulty with IV access, and the risk of complications.
# > Running step 72f512c4-3fa8-444b-80dd-637adad4b194. Step input: None
# === Calling Function ===
# Calling function: Central Venous Access Device and Site Selection query engine with args: {"input": "central line catheter selection"}
# === Function Output ===
# For central line catheter selection, several options are considered based on patient needs and clinical scenarios.
#
# 1. **Nontunneled Central Venous Catheter**: Usually appropriate for acutely ill patients requiring infusion of an irritant medication, hemodynamic monitoring, or frequent blood draws for 2 weeks or shorter. It's also usually appropriate for patients with acute renal failure requiring central venous access for renal replacement therapy anticipated to last 2 weeks or shorter.
#
# 2. **PICC (Peripherally Inserted Central Catheter)**: Usually appropriate for acutely ill patients requiring infusion of an irritant medication, hemodynamic monitoring, or frequent blood draws for 2 weeks or shorter. It may be appropriate for patients with cancer diagnosis requiring central venous access for weekly chemotherapy infusion for more than 2 weeks.
#
# 3. **Midline Catheter**: May be appropriate for certain clinical scenarios, such as administration of nonvesicant drugs over a prolonged period (6-30 days) in patients with difficult IV access or contraindication to central venous catheterization. However, it's not advocated for vesicant medications due to the risk of severe tissue injury.
#
# 4. **Tunneled Central Venous Catheter**: May be appropriate for acutely ill patients and is usually appropriate for patients requiring central venous access for more than 2 weeks, such as those with renal failure needing long-term renal replacement therapy.
#
# 5. **Arm Port and Chest Port**: Usually not appropriate for acute illness requiring short-term therapy or monitoring but are usually appropriate for patients with cancer diagnosis requiring central venous access for weekly chemotherapy infusion for more than 2 weeks.
#
# The choice of central line catheter depends on the specific clinical scenario, including the anticipated duration of therapy, the type of medication to be administered, patient factors such as difficulty with IV access, and the risk of complications.
# > Running step 05df0fb3-d14a-4228-9a90-70d3ed16cb60. Step input: None
# === LLM Response ===
# Here are some next steps in JSON format:
# ```
# {
#   "next_steps": [
#     {
#       "step": "Nontunneled Central Venous Catheter",
#       "rating": "Usually Appropriate"
#     },
#     {
#       "step": "PICC (Peripherally Inserted Central Catheter)",
#       "rating": "Usually Appropriate"
#     },
#     {
#       "step": "Midline Catheter",
#       "rating": "May be Appropriate"
#     },
#     {
#       "step": "Tunneled Central Venous Catheter",
#       "rating": "Usually Appropriate"
#     },
#     {
#       "step": "Arm Port and Chest Port",
#       "rating": "Usually Not Appropriate"
#     }
#   ]
# }
# ```
# === Function Output ===
# Here are some next steps in JSON format:
# ```
# {
#   "next_steps": [
#     {
#       "step": "Nontunneled Central Venous Catheter",
#       "rating": "Usually Appropriate"
#     },
#     {
#       "step": "PICC (Peripherally Inserted Central Catheter)",
#       "rating": "Usually Appropriate"
#     },
#     {
#       "step": "Midline Catheter",
#       "rating": "May be Appropriate"
#     },
#     {
#       "step": "Tunneled Central Venous Catheter",
#       "rating": "Usually Appropriate"
#     },
#     {
#       "step": "Arm Port and Chest Port",
#       "rating": "Usually Not Appropriate"
#     }
#   ]
# }
# ```
# === Calling Function ===
# Calling function: tool_radiologic management of iliofemoral venous thrombosis with args: {"input": "DVT treatment options"}
# > Running step fa3e389b-e9cc-4f00-84c7-663de66e896c. Step input: DVT treatment options
# Added user message to memory: DVT treatment options
# === Calling Function ===
# Calling function: Radiologic Management of Iliofemoral Venous Thrombosis query engine with args: {"input": "DVT treatment options"}
# === Function Output ===
# Treatment options for Deep Vein Thrombosis (DVT) include anticoagulation alone, catheter-directed thrombolysis (CDT), percutaneous mechanical thrombectomy (PMT), surgical thrombectomy with or without stent placement, and graded compression stocking therapy. Anticoagulation is generally the first-line therapy, while CDT and PMT may be considered for select cases of proximal DVT in severely symptomatic patients with low bleeding risk. Surgical thrombectomy and arteriovenous fistula creation may also be considered in certain situations. Graded compression stockings may be recommended for patient comfort and symptom management, but have not been shown to prevent post-thrombotic syndrome (PTS).
# > Running step 46b10d9d-6ce2-4075-a780-6487d5e6d806. Step input: None
# === LLM Response ===
# Here are the next steps with their appropriateness ratings:
# ```
# {
#   "Anticoagulation": "Usually Appropriate",
#   "Catheter-directed thrombolysis (CDT)": "May Be Appropriate",
#   "Percutaneous mechanical thrombectomy (PMT)": "May Be Appropriate",
#   "Surgical thrombectomy with or without stent placement": "May Be Appropriate",
#   "Graded compression stocking therapy": "Usually Not Appropriate for prevention of PTS"
# }
# ```
# === Function Output ===
# Here are the next steps with their appropriateness ratings:
# ```
# {
#   "Anticoagulation": "Usually Appropriate",
#   "Catheter-directed thrombolysis (CDT)": "May Be Appropriate",
#   "Percutaneous mechanical thrombectomy (PMT)": "May Be Appropriate",
#   "Surgical thrombectomy with or without stent placement": "May Be Appropriate",
#   "Graded compression stocking therapy": "Usually Not Appropriate for prevention of PTS"
# }
# ```
# === Calling Function ===
# Calling function: tool_radiologic management of iliofemoral venous thrombosis with args: {"input": "DVT stent placement"}
# > Running step 7253818e-825b-4a7d-a4b9-efceaafafae0. Step input: DVT stent placement
# Added user message to memory: DVT stent placement
# === Calling Function ===
# Calling function: Radiologic Management of Iliofemoral Venous Thrombosis query engine with args: {"input": "DVT stent placement"}
# === Function Output ===
# Stenting is often used in addition to anticoagulation for treating iliac vein obstructive lesions. While there's a general consensus on this practice, no rigorous prospective randomized controlled trials have compared it directly to anticoagulation alone. Stent placement may be beneficial, especially in cases of compression syndromes like May-Thurner Syndrome or when there are recurrent venous thromboembolisms (VTE) despite anticoagulation. However, the decision for stent placement should be made on a case-by-case basis considering the patient's specific condition and symptoms.
# > Running step 42beacaa-9442-4a20-9515-86828a99288d. Step input: None
# === LLM Response ===
# In terms of appropriateness criteria from the American College of Radiology (ACR), stent placement for DVT is considered appropriate in certain scenarios, particularly when there are significant obstructive lesions or when anticoagulation alone is insufficient to manage symptoms or prevent recurrence.
#
# Here's a breakdown based on ACR Appropriateness Criteria:
#
# - **For acute iliofemoral DVT with severe symptoms (e.g., phlegmasia cerulea dolens) not improving with anticoagulation and thrombolysis, catheter-directed therapy including stent placement may be considered usually appropriate.**
# - **In cases of chronic iliofemoral venous occlusion with significant symptoms (e.g., severe edema, pain), stenting after successful thrombolysis or as a standalone procedure for obstructive lesions can be usually appropriate.**
#
# The appropriateness ratings are based on the clinical scenario and may vary depending on the presence of specific conditions such as May-Thurner Syndrome, the severity of symptoms, and the failure of other treatments like anticoagulation.
#
# Here is an example of how next steps might be rated in a JSON format for a patient with acute iliofemoral DVT not responding to initial anticoagulation:
#
# ```json
# {
#   "next_steps": [
#     {
#       "step": "Catheter-directed thrombolysis followed by stent placement if necessary",
#       "rating": "9 (Usually Appropriate)"
#     },
#     {
#       "step": "Systemic anticoagulation alone",
#       "rating": "5 (May Be Appropriate)"
#     }
#   ]
# }
# ```
#
# This example illustrates how different management strategies for iliofemoral venous thrombosis might be rated in terms of appropriateness, with catheter-directed therapies including stent placement being considered highly appropriate in certain clinical scenarios.
# === Function Output ===
# In terms of appropriateness criteria from the American College of Radiology (ACR), stent placement for DVT is considered appropriate in certain scenarios, particularly when there are significant obstructive lesions or when anticoagulation alone is insufficient to manage symptoms or prevent recurrence.
#
# Here's a breakdown based on ACR Appropriateness Criteria:
#
# - **For acute iliofemoral DVT with severe symptoms (e.g., phlegmasia cerulea dolens) not improving with anticoagulation and thrombolysis, catheter-directed therapy including stent placement may be considered usually appropriate.**
# - **In cases of chronic iliofemoral venous occlusion with significant symptoms (e.g., severe edema, pain), stenting after successful thrombolysis or as a standalone procedure for obstructive lesions can be usually appropriate.**
#
# The appropriateness ratings are based on the clinical scenario and may vary depending on the presence of specific conditions such as May-Thurner Syndrome, the severity of symptoms, and the failure of other treatments like anticoagulation.
#
# Here is an example of how next steps might be rated in a JSON format for a patient with acute iliofemoral DVT not responding to initial anticoagulation:
#
# ```json
# {
#   "next_steps": [
#     {
#       "step": "Catheter-directed thrombolysis followed by stent placement if necessary",
#       "rating": "9 (Usually Appropriate)"
#     },
#     {
#       "step": "Systemic anticoagulation alone",
#       "rating": "5 (May Be Appropriate)"
#     }
#   ]
# }
# ```
#
# This example illustrates how different management strategies for iliofemoral venous thrombosis might be rated in terms of appropriateness, with catheter-directed therapies including stent placement being considered highly appropriate in certain clinical scenarios.
# === LLM Response ===
# To determine the best type of catheter to use for a central line, I've consulted the American College of Radiology (ACR) Appropriateness Criteria. The ACR suggests that nontunneled central venous catheters, PICC lines, and tunneled central venous catheters are usually appropriate for central line placement.
#
# Regarding your patient with a deep vein thrombosis (DVT), the decision to use a stent depends on various factors, including the severity of symptoms, the location and extent of the clot, and the patient's response to initial anticoagulation therapy. According to the ACR Appropriateness Criteria, stent placement may be considered usually appropriate in certain scenarios, such as acute iliofemoral DVT with severe symptoms not improving with anticoagulation and thrombolysis, or in cases of chronic iliofemoral venous occlusion with significant symptoms.
#
# As for why blood is red, it's due to the presence of hemoglobin, a protein in red blood cells that carries oxygen throughout the body. Hemoglobin contains a molecule called heme, which gives blood its characteristic red color.
#
# To further guide the management of your patient's DVT, could you please provide more information about their specific condition, such as the location and severity of the clot, their current symptoms, and any previous treatments they've received? This will help me provide more tailored advice based on the ACR Appropriateness Criteria.

# %%
task = agent.create_task(
    'What kind of catheter should I use for central line? '
    'On a separate note, I also want to know if my patient with a DVT needs a stent. '
    'Also, do you know why blood is red? '
)

# %%
response = agent.chat(
    'What kind of catheter should I use for central line? '
    'On a separate note, I also want to know if my patient with a DVT needs a stent. '
    'Also, do you know why blood is red? '
)
# Out:
# Added user message to memory: What kind of catheter should I use for central line? On a separate note, I also want to know if my patient with a DVT needs a stent. Also, do you know why blood is red?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 response = agent.chat(
#       2     'What kind of catheter should I use for central line? '
#       3     'On a separate note, I also want to know if my patient with a DVT needs a stent. '
#       4     'Also, do you know why blood is red? '
#       5 )
#
# File /usr/local/lib/python3.9/site-packages/wrapt/wrappers.py:670, in BoundFunctionWrapper.__call__(*args, **kwargs)
#     667             wrapped = PartialCallableObjectProxy(self.__wrapped__, instance)
#     668             return self._self_wrapper(wrapped, instance, newargs, kwargs)
# --> 670     return self._self_wrapper(self.__wrapped__, self._self_instance,
#     671             args, kwargs)
#     673 elif self._self_binding == 'callable':
#     674     if self._self_instance is None:
#     675         # This situation can occur where someone is calling the
#     676         # instancemethod via the class type and passing the instance as
#    (...)
#     679         # the wrapped function using a partial so the wrapper doesn't
#     680         # see anything as being different.
#
# File /usr/local/lib/python3.9/site-packages/llama_index/core/instrumentation/dispatcher.py:321, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     318             _logger.debug(f"Failed to reset active_span_id: {e}")
#     320 try:
# --> 321     result = func(*args, **kwargs)
#     322     if isinstance(result, asyncio.Future):
#     323         # If the result is a Future, wrap it
#     324         new_future = asyncio.ensure_future(result)
#
# File /usr/local/lib/python3.9/site-packages/llama_index/core/callbacks/utils.py:41, in trace_method.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      39 callback_manager = cast(CallbackManager, callback_manager)
#      40 with callback_manager.as_trace(trace_id):
# ---> 41     return func(self, *args, **kwargs)
#
# File /usr/local/lib/python3.9/site-packages/llama_index/core/agent/runner/base.py:647, in AgentRunner.chat(self, message, chat_history, tool_choice)
#     642     tool_choice = self.default_tool_choice
#     643 with self.callback_manager.event(
#     644     CBEventType.AGENT_STEP,
#     645     payload={EventPayload.MESSAGES: [message]},
#     646 ) as e:
# --> 647     chat_response = self._chat(
#     648         message=message,
#     649         chat_history=chat_history,
#     650         tool_choice=tool_choice,
#     651         mode=ChatResponseMode.WAIT,
#     652     )
#     653     assert isinstance(chat_response, AgentChatResponse)
#     654     e.on_end(payload={EventPayload.RESPONSE: chat_response})
#
# File /usr/local/lib/python3.9/site-packages/wrapt/wrappers.py:670, in BoundFunctionWrapper.__call__(*args, **kwargs)
#     667             wrapped = PartialCallableObjectProxy(self.__wrapped__, instance)
#     668             return self._self_wrapper(wrapped, instance, newargs, kwargs)
# --> 670     return self._self_wrapper(self.__wrapped__, self._self_instance,
#     671             args, kwargs)
#     673 elif self._self_binding == 'callable':
#     674     if self._self_instance is None:
#     675         # This situation can occur where someone is calling the
#     676         # instancemethod via the class type and passing the instance as
#    (...)
#     679         # the wrapped function using a partial so the wrapper doesn't
#     680         # see anything as being different.
#
# File /usr/local/lib/python3.9/site-packages/llama_index/core/instrumentation/dispatcher.py:321, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     318             _logger.debug(f"Failed to reset active_span_id: {e}")
#     320 try:
# --> 321     result = func(*args, **kwargs)
#     322     if isinstance(result, asyncio.Future):
#     323         # If the result is a Future, wrap it
#     324         new_future = asyncio.ensure_future(result)
#
# File /usr/local/lib/python3.9/site-packages/llama_index/core/agent/runner/base.py:579, in AgentRunner._chat(self, message, chat_history, tool_choice, mode)
#     576 dispatcher.event(AgentChatWithStepStartEvent(user_msg=message))
#     577 while True:
#     578     # pass step queue in as argument, assume step executor is stateless
# --> 579     cur_step_output = self._run_step(
#     580         task.task_id, mode=mode, tool_choice=tool_choice
#     581     )
#     583     if cur_step_output.is_last:
#     584         result_output = cur_step_output
#
# File /usr/local/lib/python3.9/site-packages/wrapt/wrappers.py:670, in BoundFunctionWrapper.__call__(*args, **kwargs)
#     667             wrapped = PartialCallableObjectProxy(self.__wrapped__, instance)
#     668             return self._self_wrapper(wrapped, instance, newargs, kwargs)
# --> 670     return self._self_wrapper(self.__wrapped__, self._self_instance,
#     671             args, kwargs)
#     673 elif self._self_binding == 'callable':
#     674     if self._self_instance is None:
#     675         # This situation can occur where someone is calling the
#     676         # instancemethod via the class type and passing the instance as
#    (...)
#     679         # the wrapped function using a partial so the wrapper doesn't
#     680         # see anything as being different.
#
# File /usr/local/lib/python3.9/site-packages/llama_index/core/instrumentation/dispatcher.py:321, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     318             _logger.debug(f"Failed to reset active_span_id: {e}")
#     320 try:
# --> 321     result = func(*args, **kwargs)
#     322     if isinstance(result, asyncio.Future):
#     323         # If the result is a Future, wrap it
#     324         new_future = asyncio.ensure_future(result)
#
# File /usr/local/lib/python3.9/site-packages/llama_index/core/agent/runner/base.py:412, in AgentRunner._run_step(self, task_id, step, input, mode, **kwargs)
#     408 # TODO: figure out if you can dynamically swap in different step executors
#     409 # not clear when you would do that by theoretically possible
#     411 if mode == ChatResponseMode.WAIT:
# --> 412     cur_step_output = self.agent_worker.run_step(step, task, **kwargs)
#     413 elif mode == ChatResponseMode.STREAM:
#     414     cur_step_output = self.agent_worker.stream_step(step, task, **kwargs)
#
# File /usr/local/lib/python3.9/site-packages/wrapt/wrappers.py:670, in BoundFunctionWrapper.__call__(*args, **kwargs)
#     667             wrapped = PartialCallableObjectProxy(self.__wrapped__, instance)
#     668             return self._self_wrapper(wrapped, instance, newargs, kwargs)
# --> 670     return self._self_wrapper(self.__wrapped__, self._self_instance,
#     671             args, kwargs)
#     673 elif self._self_binding == 'callable':
#     674     if self._self_instance is None:
#     675         # This situation can occur where someone is calling the
#     676         # instancemethod via the class type and passing the instance as
#    (...)
#     679         # the wrapped function using a partial so the wrapper doesn't
#     680         # see anything as being different.
#
# File /usr/local/lib/python3.9/site-packages/llama_index/core/instrumentation/dispatcher.py:321, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     318             _logger.debug(f"Failed to reset active_span_id: {e}")
#     320 try:
# --> 321     result = func(*args, **kwargs)
#     322     if isinstance(result, asyncio.Future):
#     323         # If the result is a Future, wrap it
#     324         new_future = asyncio.ensure_future(result)
#
# File /usr/local/lib/python3.9/site-packages/llama_index/core/callbacks/utils.py:41, in trace_method.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      39 callback_manager = cast(CallbackManager, callback_manager)
#      40 with callback_manager.as_trace(trace_id):
# ---> 41     return func(self, *args, **kwargs)
#
# File /usr/local/lib/python3.9/site-packages/llama_index/core/agent/function_calling/step.py:308, in FunctionCallingAgentWorker.run_step(self, step, task, **kwargs)
#     305 tools = self.get_tools(task.input)
#     307 # get response and tool call (if exists)
# --> 308 response = self._llm.chat_with_tools(
#     309     tools=tools,
#     310     user_msg=None,
#     311     chat_history=self.get_all_messages(task),
#     312     verbose=self._verbose,
#     313     allow_parallel_tool_calls=self.allow_parallel_tool_calls,
#     314 )
#     315 tool_calls = self._llm.get_tool_calls_from_response(
#     316     response, error_on_no_tool_call=False
#     317 )
#     318 tool_outputs: List[ToolOutput] = []
#
# File /usr/local/lib/python3.9/site-packages/llama_index/core/llms/function_calling.py:47, in FunctionCallingLLM.chat_with_tools(self, tools, user_msg, chat_history, verbose, allow_parallel_tool_calls, **kwargs)
#      38 """Chat with function calling."""
#      39 chat_kwargs = self._prepare_chat_with_tools(
#      40     tools,
#      41     user_msg=user_msg,
#    (...)
#      45     **kwargs,
#      46 )
# ---> 47 response = self.chat(**chat_kwargs)
#      48 return self._validate_chat_with_tools_response(
#      49     response,
#      50     tools,
#      51     allow_parallel_tool_calls=allow_parallel_tool_calls,
#      52     **kwargs,
#      53 )
#
# File /usr/local/lib/python3.9/site-packages/wrapt/wrappers.py:670, in BoundFunctionWrapper.__call__(*args, **kwargs)
#     667             wrapped = PartialCallableObjectProxy(self.__wrapped__, instance)
#     668             return self._self_wrapper(wrapped, instance, newargs, kwargs)
# --> 670     return self._self_wrapper(self.__wrapped__, self._self_instance,
#     671             args, kwargs)
#     673 elif self._self_binding == 'callable':
#     674     if self._self_instance is None:
#     675         # This situation can occur where someone is calling the
#     676         # instancemethod via the class type and passing the instance as
#    (...)
#     679         # the wrapped function using a partial so the wrapper doesn't
#     680         # see anything as being different.
#
# File /usr/local/lib/python3.9/site-packages/llama_index/core/instrumentation/dispatcher.py:321, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     318             _logger.debug(f"Failed to reset active_span_id: {e}")
#     320 try:
# --> 321     result = func(*args, **kwargs)
#     322     if isinstance(result, asyncio.Future):
#     323         # If the result is a Future, wrap it
#     324         new_future = asyncio.ensure_future(result)
#
# File /usr/local/lib/python3.9/site-packages/llama_index/core/llms/callbacks.py:173, in llm_chat_callback.<locals>.wrap.<locals>.wrapped_llm_chat(_self, messages, **kwargs)
#     164 event_id = callback_manager.on_event_start(
#     165     CBEventType.LLM,
#     166     payload={
#    (...)
#     170     },
#     171 )
#     172 try:
# --> 173     f_return_val = f(_self, messages, **kwargs)
#     174 except BaseException as e:
#     175     callback_manager.on_event_end(
#     176         CBEventType.LLM,
#     177         payload={EventPayload.EXCEPTION: e},
#     178         event_id=event_id,
#     179     )
#
# File /usr/local/lib/python3.9/site-packages/llama_index/llms/ollama/base.py:306, in Ollama.chat(self, messages, **kwargs)
#     303 tools = kwargs.pop("tools", None)
#     304 format = kwargs.pop("format", "json" if self.json_mode else None)
# --> 306 response = self.client.chat(
#     307     model=self.model,
#     308     messages=ollama_messages,
#     309     stream=False,
#     310     format=format,
#     311     tools=tools,
#     312     options=self._model_kwargs,
#     313     keep_alive=self.keep_alive,
#     314 )
#     316 response = dict(response)
#     318 tool_calls = response["message"].get("tool_calls", [])
#
# File /usr/local/lib/python3.9/site-packages/ollama/_client.py:332, in Client.chat(self, model, messages, tools, stream, format, options, keep_alive)
#     288 def chat(
#     289   self,
#     290   model: str = '',
#    (...)
#     297   keep_alive: Optional[Union[float, str]] = None,
#     298 ) -> Union[ChatResponse, Iterator[ChatResponse]]:
#     299   """
#     300   Create a chat response using the requested model.
#     301
#    (...)
#     330   Returns `ChatResponse` if `stream` is `False`, otherwise returns a `ChatResponse` generator.
#     331   """
# --> 332   return self._request(
#     333     ChatResponse,
#     334     'POST',
#     335     '/api/chat',
#     336     json=ChatRequest(
#     337       model=model,
#     338       messages=[message for message in _copy_messages(messages)],
#     339       tools=[tool for tool in _copy_tools(tools)],
#     340       stream=stream,
#     341       format=format,
#     342       options=options,
#     343       keep_alive=keep_alive,
#     344     ).model_dump(exclude_none=True),
#     345     stream=stream,
#     346   )
#
# File /usr/local/lib/python3.9/site-packages/ollama/_client.py:177, in Client._request(self, cls, stream, *args, **kwargs)
#     173         yield cls(**part)
#     175   return inner()
# --> 177 return cls(**self._request_raw(*args, **kwargs).json())
#
# File /usr/local/lib/python3.9/site-packages/ollama/_client.py:118, in Client._request_raw(self, *args, **kwargs)
#     117 def _request_raw(self, *args, **kwargs):
# --> 118   r = self._client.request(*args, **kwargs)
#     119   try:
#     120     r.raise_for_status()
#
# File /usr/local/lib/python3.9/site-packages/httpx/_client.py:837, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     822     warnings.warn(message, DeprecationWarning)
#     824 request = self.build_request(
#     825     method=method,
#     826     url=url,
#    (...)
#     835     extensions=extensions,
#     836 )
# --> 837 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File /usr/local/lib/python3.9/site-packages/httpx/_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File /usr/local/lib/python3.9/site-packages/httpx/_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File /usr/local/lib/python3.9/site-packages/httpx/_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File /usr/local/lib/python3.9/site-packages/httpx/_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File /usr/local/lib/python3.9/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /usr/local/lib/python3.9/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %%
agent = FunctionCallingAgent.from_tools(
    [all_pdfs_tool, fallback_tool],
    llm=Settings.llm,
    system_prompt='You are a specialized agent designed to answer queries about the planning and follow up \
    for topics related to interventional radiology based on the American College of Radiology (ACR) appropriateness criteria. \
    Answer using only information from one or more of the provided tools. \
    Do not answer from prior knowledge under any circumstances. \
    If no appropriate tool exists or if the tools do not provide sufficient context, do not answer the query. Instead, \
    indicate that the necessary information is not available in the ACR appropriateness criteria.',
    verbose=True
)

# %%
agent = FunctionCallingAgent.from_tools(
    query_engine_tools + [fallback_tool],
    llm=Settings.llm,
    system_prompt='You are a specialized agent designed to answer queries about the planning and follow up \
    for topics related to interventional radiology based on the American College of Radiology (ACR) appropriateness criteria.\
    Given clinical vignettes, you are able to tell me the most appropriate next step and why. \
    If you tell me the imaging, please be as specific as possible, including utilization of contrast or location of the imaging.\
    The PDFs you are searching have a clinical vignette, followed by a table telling you the level of \
    appropriateness of the intervention/imaging. What you need to pay attention to are the ones that say Usually Appropriate. \
    If you tell me multiple potential options or next steps, tell me which are more appropriate. If one or more options is "Usually Appropriate",\
    explicitly state so. Answer using only information from one or more of the provided tools.\
    Do not answer from prior knowledge under any circumstances. If no appropriate tool exists or if the tools do not provide sufficient\
    context, do not answer the query. Instead, indicate that the necessary information is not available in the ACR\
    appropriateness criteria. Cite your sources. Once you have an answer, stop',
    verbose=True
)

# %%
response = agent.chat(
    'What kind of catheter should I use for central line? '
    'On a separate note, I also want to know if my patient with a DVT needs a stent. '
    'Also, do you know why blood is red? '
)

# %%
response = top_agent.chat(
    '30 year old woman with fibroids who still desires pregnancy but is having trouble with fertility. What is the best next treatment plan?'
)
# Out:
# Added user message to memory: 30 year old woman with fibroids who still desires pregnancy but is having trouble with fertility. What is the best next treatment plan?
# === Calling Function ===
# Calling function: tool_management of uterine fibroids with args: {"input": "fibroids and fertility issues in a 30-year-old woman"}
# > Running step bffec16e-f97e-4423-8fb9-c3753ee10903. Step input: fibroids and fertility issues in a 30-year-old woman
# Added user message to memory: fibroids and fertility issues in a 30-year-old woman
# === Calling Function ===
# Calling function: Management of Uterine Fibroids query engine with args: {"input": "fibroids and fertility issues in a 30-year-old woman"}
# === Function Output ===
# For a 30-year-old woman experiencing fibroids and fertility issues, several treatment options are available. Laparoscopic or open myomectomy is often considered appropriate for initial therapy, as it can help improve fertility outcomes. Medical management, such as ulipristal acetate, may also be an option, particularly for women with submucosal fibroids undergoing in vitro fertilization. Additionally, MR-guided high-frequency focused ultrasound ablation (MRgFUS) and uterine artery embolization (UAE) have been shown to be effective in reducing fibroid symptoms and improving fertility outcomes. However, the choice of treatment depends on various factors, including the size and location of the fibroids, as well as the woman's overall health and desire for future pregnancy. It is essential to consult with a healthcare provider to determine the best course of treatment.
# > Running step 3ae6c20c-abcd-477d-b82e-b9d6d1c018b3. Step input: None
# === Calling Function ===
# Calling function: Management of Uterine Fibroids query engine with args: {"input": "fibroids and fertility issues in a 30-year-old woman"}
# === Function Output ===
# For a 30-year-old woman experiencing fibroids and fertility issues, several treatment options are available. Laparoscopic or open myomectomy is often considered appropriate for initial therapy, as it can help improve fertility outcomes. Medical management, such as ulipristal acetate, may also be an option, particularly for women with submucosal fibroids undergoing in vitro fertilization. Additionally, MR-guided high-frequency focused ultrasound ablation (MRgFUS) and uterine artery embolization (UAE) have been shown to be effective in reducing fibroid symptoms and improving fertility outcomes. However, the choice of treatment depends on various factors, including the size and location of the fibroids, as well as the woman's overall health and desire for future pregnancy. It is essential to consult with a healthcare provider to determine the best course of treatment.
# > Running step aaa0e179-328f-422c-94ef-1d2d6f07c8b6. Step input: None
# === LLM Response ===
# Here are some next steps based on the ACR appropriateness criteria:
# ```
# {
#   "next_steps": [
#     {
#       "step": "Laparoscopic or open myomectomy",
#       "rating": "9"
#     },
#     {
#       "step": "Medical management (e.g., ulipristal acetate)",
#       "rating": "7"
#     },
#     {
#       "step": "MR-guided high-frequency focused ultrasound ablation (MRgFUS)",
#       "rating": "6"
#     },
#     {
#       "step": "Uterine artery embolization (UAE)",
#       "rating": "5"
#     }
#   ]
# }
# ```
# These next steps are prioritized based on their appropriateness ratings, with laparoscopic or open myomectomy being the most appropriate option for a 30-year-old woman experiencing fibroids and fertility issues.
# === Function Output ===
# Here are some next steps based on the ACR appropriateness criteria:
# ```
# {
#   "next_steps": [
#     {
#       "step": "Laparoscopic or open myomectomy",
#       "rating": "9"
#     },
#     {
#       "step": "Medical management (e.g., ulipristal acetate)",
#       "rating": "7"
#     },
#     {
#       "step": "MR-guided high-frequency focused ultrasound ablation (MRgFUS)",
#       "rating": "6"
#     },
#     {
#       "step": "Uterine artery embolization (UAE)",
#       "rating": "5"
#     }
#   ]
# }
# ```
# These next steps are prioritized based on their appropriateness ratings, with laparoscopic or open myomectomy being the most appropriate option for a 30-year-old woman experiencing fibroids and fertility issues.
# === LLM Response ===
# Based on the American College of Radiology (ACR) Appropriateness Criteria, the best next treatment plan for a 30-year-old woman with fibroids who is having trouble with fertility but still desires pregnancy would be laparoscopic or open myomectomy. This procedure involves surgically removing the fibroids while leaving the uterus intact, which can help improve fertility outcomes.
#
# The ACR Appropriateness Criteria rate laparoscopic or open myomectomy as a 9 out of 9 in terms of appropriateness for this specific clinical scenario. Medical management, such as using ulipristal acetate, is rated as a 7, while MR-guided high-frequency focused ultrasound ablation (MRgFUS) and uterine artery embolization (UAE) are rated as 6 and 5, respectively.
#
# It's essential to note that the treatment plan should be individualized based on the patient's specific symptoms, fibroid location and size, and overall health status. A thorough discussion with a healthcare provider, including a radiologist and an obstetrician-gynecologist, is necessary to determine the most appropriate course of treatment.
#
# To further guide the management of this patient's condition, could you please provide more information about her specific symptoms, such as heavy menstrual bleeding or pelvic pain, and any previous treatments she's received for her fibroids? Additionally, has she undergone any fertility testing or treatments, and are there any other underlying medical conditions that may impact her fertility or treatment options?

# %%
response = agent.chat(
    'Postmenopausal patient with uterine fibroids, symptomatic with heavy uterine bleeding or \
    bulk symptoms (eg, pressure, pain, fullness, bladder, or bowel symptoms). Negative \
    endometrial biopsy. Next step.'
)

# %%
from llama_index.core import PromptTemplate

# %%
agent = ReActAgent.from_tools(
    query_engine_tools + [fallback_tool],
    llm=Settings.llm,
    verbose=True
)

# %%
agent.update_prompts({"agent_worker:system_prompt": react_system_prompt})

# %%
response = agent.chat(
    'What kind of catheter should I use for central line? '
    'On a separate note, I also want to know if my patient with a DVT needs a stent. '
    'Also, do you know why blood is red? '
)

# %% [markdown]
# ### Thoughts
# - Can use as a training tool.
# - Can be non-IR facing
# - Can be IR facing

# %% [markdown]
# ### Division of labor from here on out:
# - one person starts user interface stuff
# - one person makes the actual thing better (look into cohere api. josh said it was free)

# %% [markdown]
# ### Other Thoughts
# - I think this may be kinda shitty if we only include ACR AC. Should we think about incorporating other sources? If scaling up significantly, may need a way to filter tool selection. I think I saw how to do this somewhere.
# - What is our big-picture goal with this? Could be good for pitch. e.g., who's target market
# - Are there any benchmarks for this we can try? Could be nice to do a ChatGPT vs. our thing or something

# %% [markdown]
# ### Other to dos
# - query user for more info
# - maintain history
# - take in vignettes and also answer questions
# - Cite sources/document used
# - Gradio
# - Decide on overall agentic rag pipeline/what works best in terms of which agents/how many

# %% [markdown]
# big picture todos:
# 1. performance
# 2. interface
